# %%
import pandas as pd
import numpy as np

# %%
header_names = ['Symbol', 'Norm-Losses', 'Make', 'Fuel', 'aspiration', 'doors', 'body-style', 'drive-wheels', 'engine-loc', 'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type', 'no_of_cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price']

# %%
df = pd.read_csv('imports-85.data', sep=',', header=None, names=header_names, index_col=None, na_values='?')

# %%
pd.set_option('display.max_columns', len(df.columns))

# %%
df.head(3)
# Out:
#    Symbol  Norm-Losses         Make Fuel aspiration doors   body-style  \
# 0       3          NaN  alfa-romero  gas        std   two  convertible
# 1       3          NaN  alfa-romero  gas        std   two  convertible
# 2       1          NaN  alfa-romero  gas        std   two    hatchback
#
#   drive-wheels engine-loc  wheel-base  length  width  height  curb-weight  \
# 0          rwd      front        88.6   168.8   64.1    48.8         2548
# 1          rwd      front        88.6   168.8   64.1    48.8         2548
# 2          rwd      front        94.5   171.2   65.5    52.4         2823
#
#   engine-type no_of_cylinders  engine-size fuel-system  bore  stroke  \
# 0        dohc            four          130        mpfi  3.47    2.68
# 1        dohc            four          130        mpfi  3.47    2.68
# 2        ohcv             six          152        mpfi  2.68    3.47
#
#    compression-ratio  horsepower  peak-rpm  city-mpg  highway-mpg    price
# 0                9.0       111.0    5000.0        21           27  13495.0
# 1                9.0       111.0    5000.0        21           27  16500.0
# 2                9.0       154.0    5000.0        19           26  16500.0

# %%
df.isna().sum(axis=0).sum()
# Total NaN values in our DataFrame
# Out:
# 59

# %%
df.isna().sum(axis=0)
# Out:
# Symbol                0
# Norm-Losses          41
# Make                  0
# Fuel                  0
# aspiration            0
# doors                 2
# body-style            0
# drive-wheels          0
# engine-loc            0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# no_of_cylinders       0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
# Removing the rows which have NaN values for price
df = df.loc[df['price'].isna() == False]

# %%
# Engine-loc - boolean - front engine? Done
# Fuel - boolean - gas? Done
# parse doors into int Done
# parse no_of_cylinders to int Done
# Rename Fuel to Gas? Done

# %%
# This was something new for me, something I might have forgot to use when needed
df['engine-loc'].replace(to_replace=['front', 'rear'], value=[True, False], inplace=True)

# %%
# Symbol to int
df['Symbol'] = df['Symbol'].astype(int)

# %%
df.loc[:,'doors'].loc[df['doors'].isna()] = 'four'
# Out:
# c:\python39\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
df.loc[:, 'doors'].replace(['four', 'two'], [4, 2], inplace=True)

# %%
df.loc[:, 'Fuel'].replace(['gas', 'diesel'], [1, 0], inplace=True)

# %%
df['no_of_cylinders'].value_counts()
# df['no_of_cylinders'].isna().sum()
# Out:
# four      157
# six        24
# five       10
# two         4
# eight       4
# twelve      1
# three       1
# Name: no_of_cylinders, dtype: int64

# %%
num_cylinders = {'four': 4, 'six': 6, 'five': 5, 'two': 2, 'three': 3, 'twelve': 12}
df.replace({'no_of_cylinders': num_cylinders}, inplace=True)

# %%
# df['aspiration'].isna().sum()
df['aspiration'].value_counts()
df.loc[:, 'aspiration'].replace(['std', 'turbo'], [0, 1], inplace=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dropped_df = df.drop(['engine-size'], axis=1)

# %%
# I am dropping compression ratio because particularly, petrol cars have lesser compression-ratio as 
# compared to diesel cars because of the presence of a spark plug. More on wikipedia and can also be shown here

fig, axs = plt.subplots(1,2, figsize=(12, 6), sharey=True)
axs[0].set_title('Gas Vehicles')
axs[1].set_title('Diesel Vehicles')
sns.boxplot(ax=axs[0], y=dropped_df['compression-ratio'][dropped_df['Fuel']==1], palette='rainbow')
sns.boxplot(ax=axs[1], y=dropped_df['compression-ratio'][dropped_df['Fuel']==0], palette='Set1')

# Because of this high correlation between gas-diesel and compression-ratio we can drop it
# Out:
# <AxesSubplot:title={'center':'Diesel Vehicles'}, ylabel='compression-ratio'>

# %%
dropped_df = df.drop(['engine-size', 'compression-ratio'], axis=1)

# %%
# df
(dropped_df[['length', 'width', 'height', 'curb-weight', 'wheel-base']].corr())
# As shown there is a strong positive correlation between wheel-base and length
# As shown there is a strong positive correlation between length and width
# As shown there is a strong positive correlation between length and curb-weight and width

# So length, width, curb-weight and wheel-base share a strong positive correlation and is actually obvious

# Let's drop wheel-base and curb-weight
dropped_df.drop('wheel-base', inplace=True, axis=1)

# %%
dropped_df.drop('curb-weight', axis=1, inplace=True)

# %%
dropped_df['horsepower'].quantile(0.75)
# Out:
# 116.0

# %%
dropped_df
# Out:
#      Symbol  Norm-Losses         Make  Fuel  aspiration  doors   body-style  \
# 0         3          NaN  alfa-romero     1           0      2  convertible
# 1         3          NaN  alfa-romero     1           0      2  convertible
# 2         1          NaN  alfa-romero     1           0      2    hatchback
# 3         2        164.0         audi     1           0      4        sedan
# 4         2        164.0         audi     1           0      4        sedan
# ..      ...          ...          ...   ...         ...    ...          ...
# 200      -1         95.0        volvo     1           0      4        sedan
# 201      -1         95.0        volvo     1           1      4        sedan
# 202      -1         95.0        volvo     1           0      4        sedan
# 203      -1         95.0        volvo     0           1      4        sedan
# 204      -1         95.0        volvo     1           1      4        sedan
#
#     drive-wheels  engine-loc  length  width  height engine-type  \
# 0            rwd        True   168.8   64.1    48.8        dohc
# 1            rwd        True   168.8   64.1    48.8        dohc
# 2            rwd        True   171.2   65.5    52.4        ohcv
# 3            fwd        True   176.6   66.2    54.3         ohc
# 4            4wd        True   176.6   66.4    54.3         ohc
# ..           ...         ...     ...    ...     ...         ...
# 200          rwd        True   188.8   68.9    55.5         ohc
# 201          rwd        True   188.8   68.8    55.5         ohc
# 202          rwd        True   188.8   68.9    55.5        ohcv
# 203          rwd        True   188.8   68.9    55.5         ohc
# 204          rwd        True   188.8   68.9    55.5         ohc
#
#     no_of_cylinders fuel-system  bore  stroke  horsepower  peak-rpm  city-mpg  \
# 0                 4        mpfi  3.47    2.68       111.0    5000.0        21
# 1                 4        mpfi  3.47    2.68       111.0    5000.0        21
# 2                 6        mpfi  2.68    3.47       154.0    5000.0        19
# 3                 4        mpfi  3.19    3.40       102.0    5500.0        24
# 4                 5        mpfi  3.19    3.40       115.0    5500.0        18
# ..              ...         ...   ...     ...         ...       ...       ...
# 200               4        mpfi  3.78    3.15       114.0    5400.0        23
# 201               4        mpfi  3.78    3.15       160.0    5300.0        19
# 202               6        mpfi  3.58    2.87       134.0    5500.0        18
# 203               6         idi  3.01    3.40       106.0    4800.0        26
# 204               4        mpfi  3.78    3.15       114.0    5400.0        19
#
#      highway-mpg    price
# 0             27  13495.0
# 1             27  16500.0
# 2             26  16500.0
# 3             30  13950.0
# 4             22  17450.0
# ..           ...      ...
# 200           28  16845.0
# 201           25  19045.0
# 202           23  21485.0
# 203           27  22470.0
# 204           25  22625.0
#
# [201 rows x 22 columns]

# %%
cols = ['Symbol', 'Norm-Losses', 'Make', 'Gas?', 'std?', 'doors', 'body-style', 'drive-wheels', 'front-engine?', 'length', 'width', 'height', 'engine-type', '#cylinders', 'fuel-system', 'bore', 'stroke', 'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price']

# %%
dropped_df.rename(columns={'bore': 'bore_stroke_ratio'}, inplace=True)

# %%
dropped_df['bore_stroke_ratio'] = dropped_df['bore_stroke_ratio']/dropped_df['stroke']

# %%
dropped_df.drop('stroke', axis=1, inplace=True)

# %%
# fuel_system categorical data
# horsepower classify
# peak rpm
# mpg
# Out:
#                    Symbol  Norm-Losses         Make  Fuel  aspiration  doors  \
# 0                     3.0          NaN  alfa-romero   1.0         0.0    2.0
# 1                     3.0          NaN  alfa-romero   1.0         0.0    2.0
# 2                     1.0          NaN  alfa-romero   1.0         0.0    2.0
# 3                     2.0        164.0         audi   1.0         0.0    4.0
# 4                     2.0        164.0         audi   1.0         0.0    4.0
# ...                   ...          ...          ...   ...         ...    ...
# 201                  -1.0         95.0        volvo   1.0         1.0    4.0
# 202                  -1.0         95.0        volvo   1.0         0.0    4.0
# 203                  -1.0         95.0        volvo   0.0         1.0    4.0
# 204                  -1.0         95.0        volvo   1.0         1.0    4.0
# bore_stroke_ratio     NaN          NaN          NaN   NaN         NaN    NaN
#
#                     body-style drive-wheels  engine-loc  length  width  \
# 0                  convertible          rwd         1.0   168.8   64.1
# 1                  convertible          rwd         1.0   168.8   64.1
# 2                    hatchback          rwd         1.0   171.2   65.5
# 3                        sedan          fwd         1.0   176.6   66.2
# 4                        sedan          4wd         1.0   176.6   66.4
# ...                        ...          ...         ...     ...    ...
# 201                      sedan          rwd         1.0   188.8   68.8
# 202                      sedan          rwd         1.0   188.8   68.9
# 203                      sedan          rwd         1.0   188.8   68.9
# 204                      sedan          rwd         1.0   188.8   68.9
# bore_stroke_ratio          NaN          NaN         NaN     NaN    NaN
#
#                    height engine-type no_of_cylinders fuel-system  \
# 0                    48.8        dohc               4        mpfi
# 1                    48.8        dohc               4        mpfi
# 2                    52.4        ohcv               6        mpfi
# 3                    54.3         ohc               4        mpfi
# 4                    54.3         ohc               5        mpfi
# ...                   ...         ...             ...         ...
# 201                  55.5         ohc               4        mpfi
# 202                  55.5        ohcv               6        mpfi
# 203                  55.5         ohc               6         idi
# 204                  55.5         ohc               4        mpfi
# bore_stroke_ratio     NaN         NaN             NaN         NaN
#
#                    bore_stroke_ratio  horsepower  peak-rpm  city-mpg  \
# 0                           1.294776       111.0    5000.0      21.0
# 1                           1.294776       111.0    5000.0      21.0
# 2                           0.772334       154.0    5000.0      19.0
# 3                           0.938235       102.0    5500.0      24.0
# 4                           0.938235       115.0    5500.0      18.0
# ...                              ...         ...       ...       ...
# 201                         1.200000       160.0    5300.0      19.0
# 202                         1.247387       134.0    5500.0      18.0
# 203                         0.885294       106.0    4800.0      26.0
# 204                         1.200000       114.0    5400.0      19.0
# bore_stroke_ratio                NaN         NaN       NaN       NaN
#
#                    highway-mpg    price
# 0                         27.0  13495.0
# 1                         27.0  16500.0
# 2                         26.0  16500.0
# 3                         30.0  13950.0
# 4                         22.0  17450.0
# ...                        ...      ...
# 201                       25.0  19045.0
# 202                       23.0  21485.0
# 203                       27.0  22470.0
# 204                       25.0  22625.0
# bore_stroke_ratio          NaN      NaN
#
# [202 rows x 21 columns]
