# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install segmentation-models;

# %%
import os
import pandas as pd
import tensorflow as tf
import segmentation_models as sm
import cv2
from cv2 import imread, resize
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.python.client import device_lib
from tensorflow.keras.utils import normalize
from tensorflow.keras.metrics import MeanIoU
os.environ['TF_CPP_MIN_LOG_LEVEL']='3'

sm.set_framework('tf.keras')
sm.framework()
# Out:
# Segmentation Models: using `keras` framework.
# 'tf.keras'

# %%
seed = 42
np.random.seed = seed

# %%
def set_gpus():
    gpus = tf.config.list_physical_devices('GPU')
    if gpus:
      try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
          tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
      except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)

def get_gpus():
    info = device_lib.list_local_devices()
    return [x.physical_device_desc for x in info if x.device_type == "GPU"]

        
set_gpus()
get_gpus()
# Out:
# 1 Physical GPUs, 1 Logical GPUs
# ['device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5']

# %%
dataset_path = "/content/drive/MyDrive/dataset"
class_desc = pd.read_csv(dataset_path + "/class_dict.csv", index_col=0)

# %%
IMG_WIDTH = 128
IMG_HEIGHT = 128
IMG_CHANNELS = 3
NUM_CLASSES = len(class_desc) # 32


TRAIN_PATH = dataset_path + "/train"
TRAIN_LABELS_PATH = dataset_path + "/train_labels"
VAL_PATH = dataset_path + "/val"
VAL_LABELS_PATH = dataset_path + "/val_labels"

# %%
# Resizing the input images (for a sanity check)
train_size = len(os.listdir(TRAIN_PATH))
val_size = len(os.listdir(VAL_PATH))

# %%
def resize_images(images_path, labels_path, size, IMG_WIDTH, IMG_HEIGHT, IMG_CHANNELS):
    X = []
    y = []
    for idx, img_name in enumerate(os.listdir(images_path)[:size]):
        img_path = images_path + "/" + img_name
        img = imread(img_path)
        RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        RGB_img = resize(RGB_img, (IMG_HEIGHT, IMG_WIDTH))
        mask_path = labels_path + "/" + img_name[:-4] + "_L.png"
        mask = imread(mask_path)
        RGB_mask = cv2.cvtColor(mask, cv2.COLOR_BGR2RGB)
        if(idx == 0):
            print("Original mask shape =", RGB_mask.shape)
        RGB_mask = resize(RGB_mask, (IMG_HEIGHT, IMG_WIDTH))
        if(idx == 0):
            print("Changed mask shape =", RGB_mask.shape)
        X.append(RGB_img)
        y.append(RGB_mask)
    
    print("Done!")
    return np.array(X), np.array(y)

# %%
# For training data
X_train, y_train = resize_images(TRAIN_PATH, TRAIN_LABELS_PATH, train_size, IMG_WIDTH, IMG_HEIGHT, IMG_CHANNELS)
X_val, y_val = resize_images(VAL_PATH, VAL_LABELS_PATH, val_size, IMG_WIDTH, IMG_HEIGHT, IMG_CHANNELS)
# Out:
# Original mask shape = (720, 960, 3)
# Changed mask shape = (128, 128, 3)
# Done!
# Original mask shape = (720, 960, 3)
# Changed mask shape = (128, 128, 3)
# Done!

# %%
# Sanity check for images and masks
idx = np.random.randint(0, train_size)
img = cv2.cvtColor(X_train[idx], cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()
img = cv2.cvtColor(y_train[idx], cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()

# %%
print(f"There are a total of {len(class_desc)} classes of objects in all the images")
print("We need to encode them to 0, 1, 2, ..., 31")
# Out:
# There are a total of 32 classes of objects in all the images
# We need to encode them to 0, 1, 2, ..., 31

# %%
cls2rgb = {cl:list(class_desc.loc[cl, :]) for cl in class_desc.index}
cls2rgb
# Out:
# {'Animal': [64, 128, 64],
#  'Archway': [192, 0, 128],
#  'Bicyclist': [0, 128, 192],
#  'Bridge': [0, 128, 64],
#  'Building': [128, 0, 0],
#  'Car': [64, 0, 128],
#  'CartLuggagePram': [64, 0, 192],
#  'Child': [192, 128, 64],
#  'Column_Pole': [192, 192, 128],
#  'Fence': [64, 64, 128],
#  'LaneMkgsDriv': [128, 0, 192],
#  'LaneMkgsNonDriv': [192, 0, 64],
#  'Misc_Text': [128, 128, 64],
#  'MotorcycleScooter': [192, 0, 192],
#  'OtherMoving': [128, 64, 64],
#  'ParkingBlock': [64, 192, 128],
#  'Pedestrian': [64, 64, 0],
#  'Road': [128, 64, 128],
#  'RoadShoulder': [128, 128, 192],
#  'SUVPickupTruck': [64, 128, 192],
#  'Sidewalk': [0, 0, 192],
#  'SignSymbol': [192, 128, 128],
#  'Sky': [128, 128, 128],
#  'TrafficCone': [0, 0, 64],
#  'TrafficLight': [0, 64, 64],
#  'Train': [192, 64, 128],
#  'Tree': [128, 128, 0],
#  'Truck_Bus': [192, 128, 192],
#  'Tunnel': [64, 0, 64],
#  'VegetationMisc': [192, 192, 0],
#  'Void': [0, 0, 0],
#  'Wall': [64, 192, 0]}

# %%
def adjust_mask(mask, flat=False):
    semantic_map = []
    for colour in list(cls2rgb.values()):
        equality = np.equal(mask, colour)# 256x256x3 with True or False
        class_map = np.all(equality, axis = -1)# 256x256 If all True, then True, else False
        semantic_map.append(class_map)# List of 256x256 arrays, map of True for a given found color at the pixel, and False otherwise.
    semantic_map = np.stack(semantic_map, axis=-1)# 256x256x32 True only at the found color, and all False otherwise.
    if flat:
        semantic_map = np.reshape(semantic_map, (-1,IMG_HEIGHT*IMG_WIDTH))

    return np.float32(semantic_map)# convert to numbers

# %%
y_train_adj = adjust_mask(y_train)
y_val_adj = adjust_mask(y_val)

# %%
y_train_adj.shape
# Out:
# (601, 128, 128, 32)

# %%
activation = 'softmax'
LR = 0.0002
optim = tf.keras.optimizers.Adam(LR)

# cross_entropy_loss = sm.losses.CategoricalCELoss()
focal_loss = sm.losses.CategoricalFocalLoss()
dice_loss = sm.losses.DiceLoss()
total_loss = dice_loss + (1.5*focal_loss)

metrics= [sm.metrics.IOUScore(threshold=0.5), sm.metrics.FScore(threshold=0.5)]

BACKBONE = "resnet34"
preprocess_input = sm.get_preprocessing(BACKBONE)

callbacks_UNet = [
    tf.keras.callbacks.EarlyStopping(monitor='val_iou_score', mode="max", patience = 6, verbose=1),
    tf.keras.callbacks.ModelCheckpoint(filepath = "/content/drive/MyDrive/UNet/", monitor="val_iou_score", mode="max", verbose = 1, save_best_only=True, save_weights_only=True)
]

callbacks_LinkNet = [
    tf.keras.callbacks.EarlyStopping(monitor='val_iou_score', mode="max", patience = 6, verbose=1),
    tf.keras.callbacks.ModelCheckpoint(filepath = "/content/drive/MyDrive/LinkNet/", monitor="val_iou_score", mode="max", verbose = 1, save_best_only=True, save_weights_only=True)
]

X_train_process = preprocess_input(X_train)
X_val_process = preprocess_input(X_val)

# %%
def define_UNet(BACKBONE, activation, optimizer, loss, metrics):
    Model = sm.Unet(BACKBONE, encoder_weights='imagenet', classes=NUM_CLASSES, activation = activation)
    Model.compile(optimizer=optimizer, loss=loss, metrics=metrics)
    return Model

def define_LinkNet(BACKBONE, activation, optimizer, loss, metrics):
    Model = sm.Unet(BACKBONE, encoder_weights='imagenet', classes=NUM_CLASSES, activation = activation)
    Model.compile(optimizer=optimizer, loss=loss, metrics=metrics)
    return Model
    
# def define_PSPNet(BACKBONE, activation, optimizer, loss, metrics):
#     Model = sm.Unet(BACKBONE, encoder_weights='imagenet', classes=NUM_CLASSES, activation = activation)
#     Model.compile(optimizer=optimizer, loss=loss, metrics=metrics)
    
# def define_FPN(BACKBONE, activation, optimizer, loss, metrics):
#     Model = sm.Unet(BACKBONE, encoder_weights='imagenet', classes=NUM_CLASSES, activation = activation)
#     Model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

# %%
UNet_Model = define_UNet(BACKBONE, activation, optim, total_loss, metrics)
LinkNet_Model = define_LinkNet(BACKBONE, activation, optim, total_loss, metrics)

# %%
def train_UNet(callbacks, epochs = 20, batch_size = 8):
    print(f"Training the UNet Model")
    UNet_History = UNet_Model.fit(
        X_train_process,
        y_train_adj,
        callbacks = callbacks_UNet,
        epochs = epochs,
        batch_size = batch_size,
        verbose = 1,
        validation_data = (X_val_process, y_val_adj)
    )

def train_LinkNet(callbacks, epochs = 20, batch_size = 16):
    print(f"Training the LinkNet Model")
    LinkNet_History = LinkNet_Model.fit(
        X_train_process,
        y_train_adj,
        callbacks = callbacks_LinkNet,
        epochs = epochs,
        batch_size = batch_size,
        verbose = 2,
        validation_data = (X_val_process, y_val_adj)
    )

# %%
# UNet_History = train_UNet(callbacks_UNet, 50, 8)
# Out:
# Training the UNet Model
# Epoch 1/50
# 76/76 [==============================] - ETA: 0s - loss: 0.9786 - iou_score: 0.2517 - f1-score: 0.2603
# Epoch 1: val_iou_score improved from -inf to 0.30587, saving model to /content/drive/MyDrive/UNet/
# 76/76 [==============================] - 19s 136ms/step - loss: 0.9786 - iou_score: 0.2517 - f1-score: 0.2603 - val_loss: 0.9553 - val_iou_score: 0.3059 - val_f1-score: 0.3180
# Epoch 2/50
# 75/76 [============================>.] - ETA: 0s - loss: 0.8960 - iou_score: 0.3384 - f1-score: 0.3622
# Epoch 2: val_iou_score improved from 0.30587 to 0.34503, saving model to /content/drive/MyDrive/UNet/
# 76/76 [==============================] - 8s 104ms/step - loss: 0.8960 - iou_score: 0.3422 - f1-score: 0.3659 - val_loss: 0.9324 - val_iou_score: 0.3450 - val_f1-score: 0.3676
# Epoch 3/50
# 75/76 [============================>.] - ETA: 0s - loss: 0.8583 - iou_score: 0.3692 - f1-score: 0.3904
# Epoch 3: val_iou_score improved from 0.34503 to 0.36679, saving model to /content/drive/MyDrive/UNet/
# 76/76 [==============================] - 7s 97ms/step - loss: 0.8584 - iou_score: 0.3736 - f1-score: 0.3947 - val_loss: 0.9061 - val_iou_score: 0.3668 - val_f1-score: 0.3888
# Epoch 4/50
# 75/76 [============================>.] - ETA: 0s - loss: 0.8383 - iou_score: 0.3870 - f1-score: 0.4097
# Epoch 4: val_iou_score improved from 0.36679 to 0.40243, saving model to /content/drive/MyDrive/UNet/
# 76/76 [==============================] - 8s 101ms/step - loss: 0.8384 - iou_score: 0.3887 - f1-score: 0.4114 - val_loss: 0.8722 - val_iou_score: 0.4024 - val_f1-score: 0.4247
# Epoch 5/50
# 75/76 [============================>.] - ETA: 0s - loss: 0.8276 - iou_score: 0.3844 - f1-score: 0.4071
# Epoch 5: val_iou_score improved from 0.40243 to 0.41294, saving model to /content/drive/MyDrive/UNet/
# 76/76 [==============================] - 8s 106ms/step - loss: 0.8278 - iou_score: 0.3878 - f1-score: 0.4105 - val_loss: 0.8530 - val_iou_score: 0.4129 - val_f1-score: 0.4354
# Epoch 6/50
# 75/76 [============================>.] - ETA: 0s - loss: 0.8055 - iou_score: 0.4104 - f1-score: 0.4402
# Epoch 6: val_iou_score improved from 0.41294 to 0.43593, saving model to /content/drive/MyDrive/UNet/
# 76/76 [==============================] - 7s 97ms/step - loss: 0.8055 - iou_score: 0.4139 - f1-score: 0.4438 - val_loss: 0.8237 - val_iou_score: 0.4359 - val_f1-score: 0.4656
# Epoch 7/50
# 75/76 [============================>.] - ETA: 0s - loss: 0.7768 - iou_score: 0.4373 - f1-score: 0.4796
# Epoch 7: val_iou_score improved from 0.43593 to 0.45424, saving model to /content/drive/MyDrive/UNet/
# 76/76 [==============================] - 8s 100ms/step - loss: 0.7769 - iou_score: 0.4396 - f1-score: 0.4820 - val_loss: 0.7984 - val_iou_score: 0.4542 - val_f1-score: 0.4962
# Epoch 8/50
# 75/76 [============================>.] - ETA: 0s - loss: 0.7485 - iou_score: 0.4573 - f1-score: 0.5082
# Epoch 8: val_iou_score improved from 0.45424 to 0.47804, saving model to /content/drive/MyDrive/UNet/
# 76/76 [==============================] - 7s 97ms/step - loss: 0.7487 - iou_score: 0.4587 - f1-score: 0.5093 - val_loss: 0.7737 - val_iou_score: 0.4780 - val_f1-score: 0.5235
# Epoch 9/50
# 75/76 [============================>.] - ETA: 0s - loss: 0.7227 - iou_score: 0.4779 - f1-score: 0.5336
# Epoch 9: val_iou_score improved from 0.47804 to 0.48605, saving model to /content/drive/MyDrive/UNet/
# 76/76 [==============================] - 7s 95ms/step - loss: 0.7228 - iou_score: 0.4793 - f1-score: 0.5347 - val_loss: 0.7623 - val_iou_score: 0.4861 - val_f1-score: 0.5348
# Epoch 10/50
# 75/76 [============================>.] - ETA: 0s - loss: 0.7034 - iou_score: 0.4928 - f1-score: 0.5518
# Epoch 10: val_iou_score improved from 0.48605 to 0.48950, saving model to /content/drive/MyDrive/UNet/
# 76/76 [==============================] - 8s 107ms/step - loss: 0.7038 - iou_score: 0.4938 - f1-score: 0.5523 - val_loss: 0.7431 - val_iou_score: 0.4895 - val_f1-score: 0.5420
# Epoch 11/50
# 76/76 [==============================] - ETA: 0s - loss: 0.6842 - iou_score: 0.5077 - f1-score: 0.5700
# Epoch 11: val_iou_score improved from 0.48950 to 0.49746, saving model to /content/drive/MyDrive/UNet/
# 76/76 [==============================] - 10s 129ms/step - loss: 0.6842 - iou_score: 0.5077 - f1-score: 0.5700 - val_loss: 0.7278 - val_iou_score: 0.4975 - val_f1-score: 0.5523
# Epoch 12/50
# 76/76 [==============================] - ETA: 0s - loss: 0.6663 - iou_score: 0.5175 - f1-score: 0.5824
# Epoch 12: val_iou_score improved from 0.49746 to 0.49777, saving model to /content/drive/MyDrive/UNet/
# 76/76 [==============================] - 9s 121ms/step - loss: 0.6663 - iou_score: 0.5175 - f1-score: 0.5824 - val_loss: 0.7239 - val_iou_score: 0.4978 - val_f1-score: 0.5543
# Epoch 13/50
# 76/76 [==============================] - ETA: 0s - loss: 0.6429 - iou_score: 0.5400 - f1-score: 0.6098
# Epoch 13: val_iou_score improved from 0.49777 to 0.51353, saving model to /content/drive/MyDrive/UNet/
# 76/76 [==============================] - 10s 136ms/step - loss: 0.6429 - iou_score: 0.5400 - f1-score: 0.6098 - val_loss: 0.7116 - val_iou_score: 0.5135 - val_f1-score: 0.5712
# Epoch 14/50
# 76/76 [==============================] - ETA: 0s - loss: 0.6323 - iou_score: 0.5473 - f1-score: 0.6194
# Epoch 14: val_iou_score improved from 0.51353 to 0.51527, saving model to /content/drive/MyDrive/UNet/
# 76/76 [==============================] - 9s 123ms/step - loss: 0.6323 - iou_score: 0.5473 - f1-score: 0.6194 - val_loss: 0.7038 - val_iou_score: 0.5153 - val_f1-score: 0.5750
# Epoch 15/50
# 76/76 [==============================] - ETA: 0s - loss: 0.6226 - iou_score: 0.5506 - f1-score: 0.6246
# Epoch 15: val_iou_score improved from 0.51527 to 0.52778, saving model to /content/drive/MyDrive/UNet/
# 76/76 [==============================] - 10s 126ms/step - loss: 0.6226 - iou_score: 0.5506 - f1-score: 0.6246 - val_loss: 0.6898 - val_iou_score: 0.5278 - val_f1-score: 0.5917
# Epoch 16/50
# 75/76 [============================>.] - ETA: 0s - loss: 0.6074 - iou_score: 0.5623 - f1-score: 0.6389
# Epoch 16: val_iou_score did not improve from 0.52778
# 76/76 [==============================] - 8s 99ms/step - loss: 0.6078 - iou_score: 0.5624 - f1-score: 0.6386 - val_loss: 0.6838 - val_iou_score: 0.5225 - val_f1-score: 0.5883
# Epoch 17/50
# 75/76 [============================>.] - ETA: 0s - loss: 0.5891 - iou_score: 0.5675 - f1-score: 0.6457
# Epoch 17: val_iou_score did not improve from 0.52778
# 76/76 [==============================] - 7s 90ms/step - loss: 0.5895 - iou_score: 0.5686 - f1-score: 0.6461 - val_loss: 0.6827 - val_iou_score: 0.5122 - val_f1-score: 0.5779
# Epoch 18/50
# 75/76 [============================>.] - ETA: 0s - loss: 0.5793 - iou_score: 0.5723 - f1-score: 0.6524
# Epoch 18: val_iou_score did not improve from 0.52778
# 76/76 [==============================] - 6s 84ms/step - loss: 0.5795 - iou_score: 0.5725 - f1-score: 0.6523 - val_loss: 0.6763 - val_iou_score: 0.5152 - val_f1-score: 0.5828
# Epoch 19/50
# 75/76 [============================>.] - ETA: 0s - loss: 0.5746 - iou_score: 0.5783 - f1-score: 0.6576
# Epoch 19: val_iou_score did not improve from 0.52778
# 76/76 [==============================] - 6s 80ms/step - loss: 0.5752 - iou_score: 0.5781 - f1-score: 0.6566 - val_loss: 0.6703 - val_iou_score: 0.5164 - val_f1-score: 0.5846
# Epoch 20/50
# 75/76 [============================>.] - ETA: 0s - loss: 0.5651 - iou_score: 0.5892 - f1-score: 0.6694
# Epoch 20: val_iou_score did not improve from 0.52778
# 76/76 [==============================] - 6s 80ms/step - loss: 0.5654 - iou_score: 0.5895 - f1-score: 0.6694 - val_loss: 0.6660 - val_iou_score: 0.5086 - val_f1-score: 0.5762
# Epoch 21/50
# 75/76 [============================>.] - ETA: 0s - loss: 0.5609 - iou_score: 0.5898 - f1-score: 0.6700
# Epoch 21: val_iou_score did not improve from 0.52778
# 76/76 [==============================] - 6s 85ms/step - loss: 0.5614 - iou_score: 0.5900 - f1-score: 0.6696 - val_loss: 0.6664 - val_iou_score: 0.5145 - val_f1-score: 0.5819
# Epoch 21: early stopping

# %%
# LinkNet_History = train_LinkNet(callbacks_LinkNet, 50, 8)
# Out:
# Training the LinkNet Model
# Epoch 1/50
#
# Epoch 1: val_iou_score improved from -inf to 0.30711, saving model to /content/drive/MyDrive/LinkNet/
# 76/76 - 13s - loss: 0.9185 - iou_score: 0.3119 - f1-score: 0.3266 - val_loss: 1.0019 - val_iou_score: 0.3071 - val_f1-score: 0.3180 - 13s/epoch - 175ms/step
# Epoch 2/50
#
# Epoch 2: val_iou_score improved from 0.30711 to 0.36786, saving model to /content/drive/MyDrive/LinkNet/
# 76/76 - 8s - loss: 0.8544 - iou_score: 0.3609 - f1-score: 0.3823 - val_loss: 0.8907 - val_iou_score: 0.3679 - val_f1-score: 0.3944 - 8s/epoch - 100ms/step
# Epoch 3/50
#
# Epoch 3: val_iou_score improved from 0.36786 to 0.43339, saving model to /content/drive/MyDrive/LinkNet/
# 76/76 - 8s - loss: 0.8094 - iou_score: 0.4022 - f1-score: 0.4366 - val_loss: 0.8174 - val_iou_score: 0.4334 - val_f1-score: 0.4669 - 8s/epoch - 105ms/step
# Epoch 4/50
#
# Epoch 4: val_iou_score improved from 0.43339 to 0.45205, saving model to /content/drive/MyDrive/LinkNet/
# 76/76 - 8s - loss: 0.7650 - iou_score: 0.4442 - f1-score: 0.4932 - val_loss: 0.7883 - val_iou_score: 0.4521 - val_f1-score: 0.4968 - 8s/epoch - 101ms/step
# Epoch 5/50
#
# Epoch 5: val_iou_score did not improve from 0.45205
# 76/76 - 6s - loss: 0.7289 - iou_score: 0.4625 - f1-score: 0.5211 - val_loss: 0.7939 - val_iou_score: 0.4402 - val_f1-score: 0.4874 - 6s/epoch - 81ms/step
# Epoch 6/50
#
# Epoch 6: val_iou_score improved from 0.45205 to 0.46246, saving model to /content/drive/MyDrive/LinkNet/
# 76/76 - 8s - loss: 0.7077 - iou_score: 0.4827 - f1-score: 0.5463 - val_loss: 0.7572 - val_iou_score: 0.4625 - val_f1-score: 0.5156 - 8s/epoch - 99ms/step
# Epoch 7/50
#
# Epoch 7: val_iou_score improved from 0.46246 to 0.48525, saving model to /content/drive/MyDrive/LinkNet/
# 76/76 - 8s - loss: 0.6876 - iou_score: 0.4926 - f1-score: 0.5608 - val_loss: 0.7263 - val_iou_score: 0.4852 - val_f1-score: 0.5423 - 8s/epoch - 99ms/step
# Epoch 8/50
#
# Epoch 8: val_iou_score did not improve from 0.48525
# 76/76 - 6s - loss: 0.6696 - iou_score: 0.5079 - f1-score: 0.5787 - val_loss: 0.7169 - val_iou_score: 0.4849 - val_f1-score: 0.5451 - 6s/epoch - 81ms/step
# Epoch 9/50
#
# Epoch 9: val_iou_score improved from 0.48525 to 0.50083, saving model to /content/drive/MyDrive/LinkNet/
# 76/76 - 8s - loss: 0.6518 - iou_score: 0.5227 - f1-score: 0.5975 - val_loss: 0.7118 - val_iou_score: 0.5008 - val_f1-score: 0.5619 - 8s/epoch - 103ms/step
# Epoch 10/50
#
# Epoch 10: val_iou_score did not improve from 0.50083
# 76/76 - 6s - loss: 0.6378 - iou_score: 0.5216 - f1-score: 0.5979 - val_loss: 0.6942 - val_iou_score: 0.4934 - val_f1-score: 0.5572 - 6s/epoch - 81ms/step
# Epoch 11/50
#
# Epoch 11: val_iou_score did not improve from 0.50083
# 76/76 - 6s - loss: 0.6151 - iou_score: 0.5384 - f1-score: 0.6188 - val_loss: 0.6991 - val_iou_score: 0.4881 - val_f1-score: 0.5542 - 6s/epoch - 81ms/step
# Epoch 12/50
#
# Epoch 12: val_iou_score did not improve from 0.50083
# 76/76 - 6s - loss: 0.6114 - iou_score: 0.5469 - f1-score: 0.6278 - val_loss: 0.6833 - val_iou_score: 0.4944 - val_f1-score: 0.5639 - 6s/epoch - 78ms/step
# Epoch 13/50
#
# Epoch 13: val_iou_score did not improve from 0.50083
# 76/76 - 6s - loss: 0.5894 - iou_score: 0.5539 - f1-score: 0.6379 - val_loss: 0.6736 - val_iou_score: 0.4976 - val_f1-score: 0.5680 - 6s/epoch - 81ms/step
# Epoch 14/50
#
# Epoch 14: val_iou_score improved from 0.50083 to 0.50466, saving model to /content/drive/MyDrive/LinkNet/
# 76/76 - 7s - loss: 0.5812 - iou_score: 0.5672 - f1-score: 0.6515 - val_loss: 0.6763 - val_iou_score: 0.5047 - val_f1-score: 0.5738 - 7s/epoch - 93ms/step
# Epoch 15/50
#
# Epoch 15: val_iou_score improved from 0.50466 to 0.51584, saving model to /content/drive/MyDrive/LinkNet/
# 76/76 - 8s - loss: 0.5706 - iou_score: 0.5766 - f1-score: 0.6606 - val_loss: 0.6636 - val_iou_score: 0.5158 - val_f1-score: 0.5865 - 8s/epoch - 103ms/step
# Epoch 16/50
#
# Epoch 16: val_iou_score did not improve from 0.51584
# 76/76 - 6s - loss: 0.5604 - iou_score: 0.5853 - f1-score: 0.6708 - val_loss: 0.6675 - val_iou_score: 0.5082 - val_f1-score: 0.5775 - 6s/epoch - 77ms/step
# Epoch 17/50
#
# Epoch 17: val_iou_score improved from 0.51584 to 0.52309, saving model to /content/drive/MyDrive/LinkNet/
# 76/76 - 8s - loss: 0.5586 - iou_score: 0.5891 - f1-score: 0.6735 - val_loss: 0.6640 - val_iou_score: 0.5231 - val_f1-score: 0.5938 - 8s/epoch - 106ms/step
# Epoch 18/50
#
# Epoch 18: val_iou_score did not improve from 0.52309
# 76/76 - 6s - loss: 0.5485 - iou_score: 0.6008 - f1-score: 0.6850 - val_loss: 0.6719 - val_iou_score: 0.5110 - val_f1-score: 0.5803 - 6s/epoch - 81ms/step
# Epoch 19/50
#
# Epoch 19: val_iou_score did not improve from 0.52309
# 76/76 - 6s - loss: 0.5457 - iou_score: 0.6002 - f1-score: 0.6853 - val_loss: 0.6660 - val_iou_score: 0.5067 - val_f1-score: 0.5775 - 6s/epoch - 79ms/step
# Epoch 20/50
#
# Epoch 20: val_iou_score improved from 0.52309 to 0.52910, saving model to /content/drive/MyDrive/LinkNet/
# 76/76 - 8s - loss: 0.5434 - iou_score: 0.6052 - f1-score: 0.6897 - val_loss: 0.6561 - val_iou_score: 0.5291 - val_f1-score: 0.6002 - 8s/epoch - 99ms/step
# Epoch 21/50
#
# Epoch 21: val_iou_score improved from 0.52910 to 0.53634, saving model to /content/drive/MyDrive/LinkNet/
# 76/76 - 7s - loss: 0.5311 - iou_score: 0.6144 - f1-score: 0.6993 - val_loss: 0.6567 - val_iou_score: 0.5363 - val_f1-score: 0.6062 - 7s/epoch - 97ms/step
# Epoch 22/50
#
# Epoch 22: val_iou_score did not improve from 0.53634
# 76/76 - 6s - loss: 0.5334 - iou_score: 0.6233 - f1-score: 0.7069 - val_loss: 0.6545 - val_iou_score: 0.5313 - val_f1-score: 0.6015 - 6s/epoch - 81ms/step
# Epoch 23/50
#
# Epoch 23: val_iou_score improved from 0.53634 to 0.53701, saving model to /content/drive/MyDrive/LinkNet/
# 76/76 - 8s - loss: 0.5333 - iou_score: 0.6265 - f1-score: 0.7097 - val_loss: 0.6581 - val_iou_score: 0.5370 - val_f1-score: 0.6073 - 8s/epoch - 99ms/step
# Epoch 24/50
#
# Epoch 24: val_iou_score did not improve from 0.53701
# 76/76 - 6s - loss: 0.5266 - iou_score: 0.6265 - f1-score: 0.7095 - val_loss: 0.6474 - val_iou_score: 0.5294 - val_f1-score: 0.6011 - 6s/epoch - 81ms/step
# Epoch 25/50
#
# Epoch 25: val_iou_score improved from 0.53701 to 0.53979, saving model to /content/drive/MyDrive/LinkNet/
# 76/76 - 8s - loss: 0.5256 - iou_score: 0.6280 - f1-score: 0.7116 - val_loss: 0.6474 - val_iou_score: 0.5398 - val_f1-score: 0.6128 - 8s/epoch - 102ms/step
# Epoch 26/50
#
# Epoch 26: val_iou_score did not improve from 0.53979
# 76/76 - 6s - loss: 0.5208 - iou_score: 0.6333 - f1-score: 0.7168 - val_loss: 0.6469 - val_iou_score: 0.5369 - val_f1-score: 0.6084 - 6s/epoch - 81ms/step
# Epoch 27/50
#
# Epoch 27: val_iou_score improved from 0.53979 to 0.54344, saving model to /content/drive/MyDrive/LinkNet/
# 76/76 - 7s - loss: 0.5209 - iou_score: 0.6355 - f1-score: 0.7179 - val_loss: 0.6459 - val_iou_score: 0.5434 - val_f1-score: 0.6155 - 7s/epoch - 97ms/step
# Epoch 28/50
#
# Epoch 28: val_iou_score improved from 0.54344 to 0.54952, saving model to /content/drive/MyDrive/LinkNet/
# 76/76 - 7s - loss: 0.5159 - iou_score: 0.6380 - f1-score: 0.7204 - val_loss: 0.6434 - val_iou_score: 0.5495 - val_f1-score: 0.6215 - 7s/epoch - 97ms/step
# Epoch 29/50
#
# Epoch 29: val_iou_score did not improve from 0.54952
# 76/76 - 6s - loss: 0.5115 - iou_score: 0.6407 - f1-score: 0.7237 - val_loss: 0.6512 - val_iou_score: 0.5356 - val_f1-score: 0.6057 - 6s/epoch - 81ms/step
# Epoch 30/50
#
# Epoch 30: val_iou_score did not improve from 0.54952
# 76/76 - 6s - loss: 0.5067 - iou_score: 0.6428 - f1-score: 0.7259 - val_loss: 0.6428 - val_iou_score: 0.5399 - val_f1-score: 0.6118 - 6s/epoch - 82ms/step
# Epoch 31/50
#
# Epoch 31: val_iou_score did not improve from 0.54952
# 76/76 - 6s - loss: 0.5002 - iou_score: 0.6456 - f1-score: 0.7284 - val_loss: 0.6420 - val_iou_score: 0.5331 - val_f1-score: 0.6046 - 6s/epoch - 77ms/step
# Epoch 32/50
#
# Epoch 32: val_iou_score did not improve from 0.54952
# 76/76 - 6s - loss: 0.5004 - iou_score: 0.6492 - f1-score: 0.7322 - val_loss: 0.6432 - val_iou_score: 0.5358 - val_f1-score: 0.6065 - 6s/epoch - 76ms/step
# Epoch 33/50
#
# Epoch 33: val_iou_score did not improve from 0.54952
# 76/76 - 6s - loss: 0.5060 - iou_score: 0.6416 - f1-score: 0.7234 - val_loss: 0.6483 - val_iou_score: 0.5476 - val_f1-score: 0.6179 - 6s/epoch - 81ms/step
# Epoch 34/50
#
# Epoch 34: val_iou_score did not improve from 0.54952
# 76/76 - 6s - loss: 0.5047 - iou_score: 0.6406 - f1-score: 0.7227 - val_loss: 0.6408 - val_iou_score: 0.5469 - val_f1-score: 0.6183 - 6s/epoch - 77ms/step
# Epoch 34: early stopping

# %%
# print(f"Training the PSPNet Model")
# PSPNet_History = PSPNet_Model.fit(
#     X_train_process,
#     y_train_adj,
#     callbacks = callbacks,
#     epochs = 5,
#     batch_size = 4,
#     verbose = 1,
#     validation_data = (X_val_process, y_val_adj)
# )

# %%
# print(f"Training the FPN Model")
# FPN_History = FPN_Model.fit(
#     X_train_process,
#     y_train_adj,
#     callbacks = callbacks,
#     epochs = 5,
#     batch_size = 4,
#     verbose = 1,
#     validation_data = (X_val_process, y_val_adj)
# )

# %%
models = [UNet_Model, LinkNet_Model]
model_names = ["UNet", "LinkNet"]

# %%
for i in range(len(models)):
    loss = models[i].history.history['iou_score']
    val_loss = models[i].history.history['val_iou_score']
    epochs = range(1, len(loss)+1)
    plt.plot(epochs, loss, 'y', label='Training IOU Score')
    plt.plot(epochs, val_loss, 'r', label='Val IOU Score')
    plt.title(f"Training and Validation IOU Scores for {model_names[i]}")
    plt.xlabel('Epochs')
    plt.ylabel("IOU Score")
    plt.legend()
    plt.show()

# %% [markdown]
# #### Clearly, UNet starts overfitting the data after 20 epochs but thanks to **ModelCheckpoints**, we save the best model in terms of the *validation IOU score*.

# %%
idx2rgb={idx:np.array(rgb) for idx, (cl, rgb) in enumerate(cls2rgb.items())}

def map_class_to_rgb(p):
  return idx2rgb[p[0]]

# %%
def predict_mask(img, model):
    "Given an image of size (128, 128, 3), predict the segmented mask of img by the model."
    test_img = img.reshape((1, IMG_WIDTH, IMG_HEIGHT, IMG_CHANNELS))
    prediction = (model.predict(test_img))
    prediction = np.argmax(prediction, axis=-1)
    rgb_mask = np.apply_along_axis(map_class_to_rgb, -1, np.expand_dims(prediction, -1))
    rgb_mask = rgb_mask.reshape((IMG_WIDTH, IMG_HEIGHT, IMG_CHANNELS))
    return rgb_mask

# %%
idx = np.random.randint(0, len(X_val))

fig, axs = plt.subplots(2, 2, figsize = (10, 10))
axs[0, 0].set_title("Original Image")
axs[0, 0].imshow(X_val[idx])
axs[0, 1].set_title("Ground Truth")
axs[0, 1].imshow(y_val[idx])
axs[1, 0].set_title(model_names[0])
axs[1, 0].imshow(predict_mask(X_val_process[idx], models[0]))
axs[1, 1].set_title(model_names[1])
axs[1, 1].imshow(predict_mask(X_val_process[idx], models[1]))

# %%
# Saving Models
# UNet_Model.save(filepath = "/content/drive/MyDrive/UNet")
# LinkNet_Model.save(filepath = "/content/drive/MyDrive/LinkNet")
# Out:
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/UNet/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/LinkNet/assets

# %%
loaded_UNet = define_UNet(BACKBONE, activation, optim, total_loss, metrics)
loaded_UNet.load_weights("/content/drive/MyDrive/UNet")
loaded_LinkNet = define_LinkNet(BACKBONE, activation, optim, total_loss, metrics)
loaded_LinkNet.load_weights("/content/drive/MyDrive/LinkNet")

# %%
idx = np.random.randint(0, len(X_val))

fig, axs = plt.subplots(2, 2, figsize = (10, 10))
axs[0, 0].set_title("Original Image")
axs[0, 0].imshow(X_val[idx])
axs[0, 1].set_title("Ground Truth")
axs[0, 1].imshow(y_val[idx])
axs[1, 0].set_title(model_names[0])
axs[1, 0].imshow(predict_mask(X_val_process[idx], loaded_UNet))
axs[1, 1].set_title(model_names[1])
axs[1, 1].imshow(predict_mask(X_val_process[idx], loaded_LinkNet))
